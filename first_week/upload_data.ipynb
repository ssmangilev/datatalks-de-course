# %%
import pandas as pd
pd.__version__
# Out:
# '1.4.4'

# %%
import pyarrow.parquet as pq
df = pq.read_table(source="yellow_tripdata_2022-01.parquet").to_pandas()
# Out:
# {'_is_copy': None, '_mgr': BlockManager
# Items: Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')
# Axis 1: RangeIndex(start=0, stop=2463931, step=1)
# NumericBlock: [0 7 8 9], 4 x 2463931, dtype: int64
# DatetimeLikeBlock: slice(1, 3, 1), 2 x 2463931, dtype: datetime64[ns]
# NumericBlock: [ 3  4  5 10 11 12 13 14 15 16 17 18], 12 x 2463931, dtype: float64
# ObjectBlock: slice(6, 7, 1), 1 x 2463931, dtype: object, '_item_cache': {}, '_attrs': {}, '_flags': <Flags(allows_duplicate_labels=True)>}

# %%
for i in df.items():
    print(i)
# Out:
# ('VendorID', 0          1
# 1          1
# 2          2
# 3          2
# 4          2
#           ..
# 2463926    2
# 2463927    2
# 2463928    2
# 2463929    2
# 2463930    2
# Name: VendorID, Length: 2463931, dtype: int64)
# ('tpep_pickup_datetime', 0         2022-01-01 00:35:40
# 1         2022-01-01 00:33:43
# 2         2022-01-01 00:53:21
# 3         2022-01-01 00:25:21
# 4         2022-01-01 00:36:48
#                   ...
# 2463926   2022-01-31 23:36:53
# 2463927   2022-01-31 23:44:22
# 2463928   2022-01-31 23:39:00
# 2463929   2022-01-31 23:36:42
# 2463930   2022-01-31 23:46:00
# Name: tpep_pickup_datetime, Length: 2463931, dtype: datetime64[ns])
# ('tpep_dropoff_datetime', 0         2022-01-01 00:53:29
# 1         2022-01-01 00:42:07
# 2         2022-01-01 01:02:19
# 3         2022-01-01 00:35:23
# 4         2022-01-01 01:14:20
#                   ...
# 2463926   2022-01-31 23:42:51
# 2463927   2022-01-31 23:55:01
# 2463928   2022-01-31 23:50:00
# ...
